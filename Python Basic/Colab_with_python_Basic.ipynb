# %% [markdown]
# # 깃허브 연동모듈

# %%
from google.colab import drive  
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-744eae482a40> in <module>
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.8/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      99 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#     100   """Mount your Google Drive at the specified mountpoint path."""
# --> 101   return _mount(
#     102       mountpoint,
#     103       force_remount=force_remount,
#
# /usr/local/lib/python3.8/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     122       'TBE_EPHEM_CREDS_ADDR'] if ephemeral else _os.environ['TBE_CREDS_ADDR']
#     123   if ephemeral:
# --> 124     _message.blocking_request(
# ...

# %%
cd /content/drive/MyDrive/03. data science /01. With Python/Basic.git/Python Basic
# Out:
# /content/drive/MyDrive/03. data science /01. With Python/Basic.git/Python Basic

# %%
# !git config --global user.email 'h4zhistory@gmail.com'  
# !git config --global user.name 'RichardChungLabs
# Out:
# /bin/bash: -c: line 0: unexpected EOF while looking for matching `''
# /bin/bash: -c: line 1: syntax error: unexpected end of file

# %%
# !git add Colab_with_python_Basic.ipynb

# %%
# !git commit -m 'Colab_with_python_Basic.ipynb'
# Out:
# [main d728085] Colab_with_python_Basic.ipynb
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite Python Basic/Colab_with_python_Basic.ipynb (98%)

# %%
# !git push
# Out:
# Counting objects: 4, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 5.43 KiB | 926.00 KiB/s, done.
# Total 4 (delta 1), reused 0 (delta 0)
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/RichardChungLabs/Withpython
#    7a1817f..d728085  main -> main

# %% [markdown]
# # 파이선 기초 문법 정리
# ---
# **파이선 문법 (Colab_with_python_Basic.ipynb)**
#
# (1) 자료형 (숫자, 시퀀스, 매핑, 불, 세트, 문자열슬라이싱)
# (2) 제어문 (if, while, for)
# (3) 클래스 부터 패키지 (함수, 클래스, 모듈, 패키지, 예외처리, 내장함수, 표준, 외부 라이브러리
# (4) 객체지향  (클래스 와 인스턴스, 변수와 메서드, 상속, 객체 속의 객체, 특별한 메서드)
# (5) 간단한 파이선 프로그램  (사칙연산 함수, 구구단, 비밀번호 생성, 암호만들기, ...)

# %% [markdown]
# **(1) 자료형**
# *   숫자
# 숫자를 나타내는 자료형으로는 정수(int), 부동소수점수(float), 복소수(complex)
#
# *   시퀀스
# 문자열(str), 리스트(list), 튜플(tuple), 사용자 정의 클래스가 시퀀스에 속합니다.
#
# *   매핑
# 딕셔너리(dict)는 키(key)와 값(value)의 짝으로 이뤄집니다. 이런 것을 매핑이라고 합니다.
#
# *   불
# 참, 거짓을 표현하는 불(bool)도 있습니다
#
# *   세트
# 집합을 표현하는 세트(set)도 있습니다.

# %% [markdown]
# *  문자열 슬라이싱
#
# -아래와 같이 문자열 인덱스를 이용해 문자열의 일부를 복사할 수 있습니다.
# p = 'Python'
# p[0:2]
# 'Py'
#
# -시작 인덱스가 0일 때는 아래처럼 콤마 앞의 0을 생략할 수도 있습니다.
# p[:2]
# 'Py'
#
# -음수 인덱스를 사용해 문자열의 뒷부분을 복사할 수도 있습니다.
# p[-2:]
# 'on'
#
# -다음과 같이 콤마의 앞뒤 숫자를 모두 생략하면 문자열 전부를 복사할 수 있습니다.
# p[:]
# 'Python'
#
# -역순으로 복사하는 것도 가능합니다.
# p[::-1]
# 'nohtyP'

# %% [markdown]
# #    **(1)자료형**
# **숫자**

# %% [markdown]
# x의 y제곱을 나타내는 ** 연산자

# %%
x=3
y=4

# %%
z1= x**y

# %%
z1
# Out:
# 81

# %% [markdown]
# 나눗셈 후 나머지를 반환하는 % 연산자

# %%
z2= 4%3

# %%
z2
# Out:
# 1

# %% [markdown]
# 나눗셈 후 몫을 반환하는 // 연산자

# %%
z3=y/x #(몫과 나머지)

# %%
z4=y//xv #(몫)

# %%
z3,z4
# Out:
# (1.3333333333333333, 1)

# %% [markdown]
#  **시퀀스**
# {문자열(str), 리스트(list), 튜플(tuple), 사용자 정의 클래스가 시퀀스에 속합니다.}

# %% [markdown]
#
#
# *   문자열 : https://wikidocs.net/13
# *   리스트 : https://wikidocs.net/14
# 숫자와 문자열만으로 프로그래밍을 하기엔 부족한 점이 많다. 예를 들어 1부터 10까지의 숫자 중 홀수 모음인 1, 3, 5, 7, 9의 집합을 생각해 보자. 이런 숫자 모음을 숫자나 문자열로 표현하기는 쉽지 않다. 파이썬에는 이러한 불편함을 해소할 수 있는 자료형이 존재한다. 그것이 바로 여기에서 공부할 리스트(List)이다.
# *   튜플   : https://wikidocs.net/15
# 리스트는 [ ]으로 둘러싸지만 튜플은 ( )으로 둘러싼다.
# 리스트는 요소 값의 생성, 삭제, 수정이 가능하지만 튜플은 요소 값을 바꿀 수 없다.
# *   사용자 정의 함수 : https://wikidocs.net/24
# def add(a, b):  # a, b는 매개변수
#     return a+b
# print(add(3, 4))  # 3, 4는 인수

# %% [markdown]
# **매핑**
#
# 딕셔너리(dict)는 키(key)와 값(value)의 짝으로 이뤄집니다. 이런 것을 매핑이라고 합니다.
# 딕셔너리는 리스트나 튜플처럼 순차적으로(sequential) 해당 요솟값을 구하지 않고 Key를 통해 Value를 얻는다. 이것이 바로 딕셔너리의 가장 큰 특징
#
# https://wikidocs.net/16

# %%
a = {'name': 'pey', 'phone': '010-9999-1234', 'birth': '1118'}
a.keys()
# Out:
# dict_keys(['name', 'phone', 'birth'])

# %% [markdown]
# **집합**
# https://wikidocs.net/1015
#
# 중복을 허용하지 않는다.
# 순서가 없다(Unordered).
# 중복을 허용하지 특징 때문에 set은 자료형의 중복을 제거하기 위한 필터로 종종 사용된다.

# %% [markdown]
# **불**
# https://wikidocs.net/17
# 불(bool) 자료형이란 참(True)과 거짓(False)을 나타내는 자료형이다. 불 자료형은 다음 2가지 값만을 가질 수 있다.
#
# True - 참
# False - 거짓
# True나 False는 파이썬의 예약어로 true, false와 같이 사용하지 말고 첫 문자를 항상 대문자로 사용해야 한다.

# %% [markdown]
# # **(2)제어문**
# *   if, while, for 등의 제어문
#
# *   if : https://wikidocs.net/20 , https://wikidocs.net/57
# *   while : https://wikidocs.net/21 , https://wikidocs.net/56
# *   for : https://wikidocs.net/22 , https://wikidocs.net/58
# *   match-case : https://wikidocs.net/173398

# %%
money = 2000
card = True
if money >= 3000 or card:
  print("택시를 타고 가라")
else:
  print("걸어가라")
# Out:
# 택시를 타고 가라

# %% [markdown]
# # **(3) 함수, 클래스 부터 패키지**
